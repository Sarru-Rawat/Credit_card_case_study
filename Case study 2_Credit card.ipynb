# %%
import pandas as pd

# %%
Customer_acquistion=pd.read_csv("C:\\Users\\d\\OneDrive\\Desktop\\Python Study Material\\Case studies\\case study 2\\Customer Acqusition.csv")
Repayment=pd.read_csv("C:\\Users\\d\\OneDrive\\Desktop\\Python Study Material\\Case studies\\case study 2\\Repayment.csv")
spend=pd.read_csv("C:\\Users\\d\\OneDrive\\Desktop\\Python Study Material\\Case studies\\case study 2\\spend.csv")

# %%
Credit_card_data=pd.read_excel("C:\\Users\d\\OneDrive\\Desktop\\Python Study Material\\Case studies\\case study 2\\Credit Card Data.xlsx")

# %%
Customer_acquistion
# Out:
#      No Customer  Age        City   Product     Limit Company        Segment
# 0     1       A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...  ...         ...       ...       ...     ...            ...
# 95   96      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
Customer_acquistion[Customer_acquistion.Age<18]= Customer_acquistion.Age.mean()

# %%
Customer_acquisition_spend=pd.merge(left=Customer_acquistion,right=spend,on='Customer')
Customer_acquisition_spend
# Out:
#        No Customer  Age        City   Product     Limit Company  \
# 0       1       A1   76   BANGALORE      Gold  500000.0      C1
# 1       1       A1   76   BANGALORE      Gold  500000.0      C1
# 2       1       A1   76   BANGALORE      Gold  500000.0      C1
# 3       1       A1   76   BANGALORE      Gold  500000.0      C1
# 4       1       A1   76   BANGALORE      Gold  500000.0      C1
# ...   ...      ...  ...         ...       ...       ...     ...
# 1495   96      A96   54     CHENNAI    Silver  100000.0     C19
# 1496   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98   51    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99   35    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100   36      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount
# 0     Self Employed       1  12-Jan-04   JEWELLERY  485470.80
# 1     Self Employed       2   3-Jan-04       PETRO  410556.13
# ...

# %%
Customer_acquisition_spend.drop(columns='Sl No:',inplace=True)

# %%
Customer_acquisition_spend
# Out:
#        No Customer  Age        City   Product     Limit Company  \
# 0       1       A1   76   BANGALORE      Gold  500000.0      C1
# 1       1       A1   76   BANGALORE      Gold  500000.0      C1
# 2       1       A1   76   BANGALORE      Gold  500000.0      C1
# 3       1       A1   76   BANGALORE      Gold  500000.0      C1
# 4       1       A1   76   BANGALORE      Gold  500000.0      C1
# ...   ...      ...  ...         ...       ...       ...     ...
# 1495   96      A96   54     CHENNAI    Silver  100000.0     C19
# 1496   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98   51    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99   35    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100   36      COCHIN    Silver  100000.0      C5
#
#             Segment      Month        Type     Amount
# 0     Self Employed  12-Jan-04   JEWELLERY  485470.80
# 1     Self Employed   3-Jan-04       PETRO  410556.13
# ...

# %%
Customer_acquisition_spend.loc[Customer_acquisition_spend.Amount>Customer_acquisition_spend.Limit,'Amount']=Customer_acquisition_spend.Limit*0.5

# %%
Customer_acquisition_repayment=pd.merge(left=Customer_acquistion,right=Repayment,on='Customer')

# %%
Customer_acquisition_repayment.drop(columns='SL No:',inplace=True)

# %%
Customer_acquisition_repayment
# Out:
#        No Customer  Age        City   Product     Limit Company  \
# 0       1       A1   76   BANGALORE      Gold  500000.0      C1
# 1       1       A1   76   BANGALORE      Gold  500000.0      C1
# 2       1       A1   76   BANGALORE      Gold  500000.0      C1
# 3       1       A1   76   BANGALORE      Gold  500000.0      C1
# 4       1       A1   76   BANGALORE      Gold  500000.0      C1
# ...   ...      ...  ...         ...       ...       ...     ...
# 1495   96      A96   54     CHENNAI    Silver  100000.0     C19
# 1496   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98   51    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99   35    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100   36      COCHIN    Silver  100000.0      C5
#
#             Segment      Month     Amount  Unnamed: 4
# 0     Self Employed  12-Jan-04  495414.75         NaN
# 1     Self Employed   3-Jan-04  245899.02         NaN
# ...

# %%
Customer_acquisition_repayment.loc[Customer_acquisition_spend.Amount>Customer_acquisition_repayment.Limit,'Amount']=Customer_acquisition_spend.Limit

# %%
Customer_acquistion.Customer.value_counts()   ## we have 100 distinct customers
# Out:
# A1      1
# A64     1
# A74     1
# A73     1
# A72     1
#        ..
# A31     1
# A30     1
# A29     1
# A28     1
# A100    1
# Name: Customer, Length: 100, dtype: int64

# %%
Customer_acquistion.Segment.value_counts()
# Out:
# Govt             29
# Self Employed    23
# Normal Salary    22
# Salaried_MNC     13
# Salaried_Pvt     13
# Name: Segment, dtype: int64

# %%
spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl No:    1500 non-null   int64
#  1   Customer  1500 non-null   object
#  2   Month     1500 non-null   object
#  3   Type      1500 non-null   object
#  4   Amount    1500 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 58.7+ KB

# %%
spend.Month=pd.to_datetime(spend['Month'])

# %%
spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl No:    1500 non-null   int64
#  1   Customer  1500 non-null   object
#  2   Month     1500 non-null   datetime64[ns]
#  3   Type      1500 non-null   object
#  4   Amount    1500 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 58.7+ KB

# %%
spend['spend_month']=spend.Month.apply(lambda x : pd.datetime.strftime(x, format='%b'))
# Out:
# C:\Users\d\AppData\Local\Temp\ipykernel_10724\1920433079.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   spend['spend_month']=spend.Month.apply(lambda x : pd.datetime.strftime(x, format='%b'))

# %%
spend
# Out:
#       Sl No: Customer      Month        Type     Amount spend_month
# 0          1       A1 2004-01-12   JEWELLERY  485470.80         Jan
# 1          2       A1 2004-01-03       PETRO  410556.13         Jan
# 2          3       A1 2004-01-15     CLOTHES   23740.46         Jan
# 3          4       A1 2004-01-25        FOOD  484342.47         Jan
# 4          5       A1 2005-01-17      CAMERA  369694.07         Jan
# ...      ...      ...        ...         ...        ...         ...
# 1495    1496      A67 2006-02-04  BUS TICKET  356872.73         Feb
# 1496    1497      A68 2006-03-25  BUS TICKET  204971.10         Mar
# 1497    1498      A69 2006-03-31  BUS TICKET   50449.44         Mar
# 1498    1499      A70 2006-03-23  BUS TICKET   80593.94         Mar
# 1499    1500      A71 2006-03-24  BUS TICKET  194447.62         Mar
#
# [1500 rows x 6 columns]

# %%
spend.groupby(by=['Customer','spend_month']).Amount.mean().round(2)
# Out:
# Customer  spend_month
# A1        Apr            261649.25
#           Aug            344372.10
#           Feb            175235.69
#           Jan            372762.59
#           May            361141.31
#                            ...
# A95       Jan            240401.50
# A96       Jan             54729.66
# A97       Jan            139018.26
# A98       Jan            284521.06
# A99       Jan             90184.22
# Name: Amount, Length: 578, dtype: float64

# %%
Repayment.Month=pd.to_datetime(Repayment['Month'])

# %%
Repayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1523 entries, 0 to 1522
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SL No:      1499 non-null   float64
#  1   Customer    1500 non-null   object
#  2   Month       1500 non-null   datetime64[ns]
#  3   Amount      1500 non-null   float64
#  4   Unnamed: 4  0 non-null      float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 59.6+ KB

# %%
Repayment.dropna(axis=0,how='all',inplace=True)
Repayment
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1 2004-01-12  495414.75         NaN
# 1        2.0       A1 2004-01-03  245899.02         NaN
# 2        3.0       A1 2004-01-15  259490.06         NaN
# 3        4.0       A1 2004-01-25  437555.12         NaN
# 4        5.0       A1 2005-01-17  165972.88         NaN
# ...      ...      ...        ...        ...         ...
# 1495  1496.0      A67 2005-05-09   55638.77         NaN
# 1496  1497.0      A68 2006-05-10  319836.49         NaN
# 1497  1498.0      A69 2006-07-11  247628.45         NaN
# 1498  1499.0      A70 2005-08-12  454016.51         NaN
# 1499  1500.0      A71 2004-09-13   56286.33         NaN
#
# [1500 rows x 5 columns]

# %%
Repayment['Repay_month']=Repayment.Month.apply(lambda x : pd.datetime.strftime(x, format='%b'))
# Out:
# C:\Users\d\AppData\Local\Temp\ipykernel_10724\2592588893.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   Repayment['Repay_month']=Repayment.Month.apply(lambda x : pd.datetime.strftime(x, format='%b'))

# %%
Repayment
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4 Repay_month
# 0        NaN       A1 2004-01-12  495414.75         NaN         Jan
# 1        2.0       A1 2004-01-03  245899.02         NaN         Jan
# 2        3.0       A1 2004-01-15  259490.06         NaN         Jan
# 3        4.0       A1 2004-01-25  437555.12         NaN         Jan
# 4        5.0       A1 2005-01-17  165972.88         NaN         Jan
# ...      ...      ...        ...        ...         ...         ...
# 1495  1496.0      A67 2005-05-09   55638.77         NaN         May
# 1496  1497.0      A68 2006-05-10  319836.49         NaN         May
# 1497  1498.0      A69 2006-07-11  247628.45         NaN         Jul
# 1498  1499.0      A70 2005-08-12  454016.51         NaN         Aug
# 1499  1500.0      A71 2004-09-13   56286.33         NaN         Sep
#
# [1500 rows x 6 columns]

# %%
Repayment.groupby(by=['Customer','Repay_month']).Amount.mean().round(2)
# Out:
# Customer  Repay_month
# A1        Apr            254474.58
#           Feb            156374.76
#           Jan            343972.33
#           Jul            297176.74
#           Nov            285729.09
#                            ...
# A95       Jan            369405.96
# A96       Jan            310992.30
# A97       Jan            121874.90
# A98       Jan            337815.57
# A99       Jan             25682.73
# Name: Amount, Length: 558, dtype: float64

# %%
Repayment.dropna(axis=1,how='all',inplace=True)

# %%
Repayment
# Out:
#       SL No: Customer      Month     Amount Repay_month
# 0        NaN       A1 2004-01-12  495414.75         Jan
# 1        2.0       A1 2004-01-03  245899.02         Jan
# 2        3.0       A1 2004-01-15  259490.06         Jan
# 3        4.0       A1 2004-01-25  437555.12         Jan
# 4        5.0       A1 2005-01-17  165972.88         Jan
# ...      ...      ...        ...        ...         ...
# 1495  1496.0      A67 2005-05-09   55638.77         May
# 1496  1497.0      A68 2006-05-10  319836.49         May
# 1497  1498.0      A69 2006-07-11  247628.45         Jul
# 1498  1499.0      A70 2005-08-12  454016.51         Aug
# 1499  1500.0      A71 2004-09-13   56286.33         Sep
#
# [1500 rows x 5 columns]

# %%
Repay_spend=pd.merge(left=spend,right=Repayment,left_on=['Customer','spend_month'],right_on=['Customer','Repay_month'])

# %%
Repay_spend
# Out:
#       Sl No: Customer    Month_x       Type   Amount_x spend_month  SL No:  \
# 0          1       A1 2004-01-12  JEWELLERY  485470.80         Jan     NaN
# 1          1       A1 2004-01-12  JEWELLERY  485470.80         Jan     2.0
# 2          1       A1 2004-01-12  JEWELLERY  485470.80         Jan     3.0
# 3          1       A1 2004-01-12  JEWELLERY  485470.80         Jan     4.0
# 4          1       A1 2004-01-12  JEWELLERY  485470.80         Jan     5.0
# ...      ...      ...        ...        ...        ...         ...     ...
# 5311    1374      A44 2006-12-03  JEWELLERY  313591.17         Dec   997.0
# 5312    1441      A53 2005-04-27  JEWELLERY  129641.87         Apr  1035.0
# 5313    1441      A53 2005-04-27  JEWELLERY  129641.87         Apr  1151.0
# 5314    1441      A53 2005-04-27  JEWELLERY  129641.87         Apr  1325.0
# 5315    1483      A56 2006-12-03  JEWELLERY  223628.27         Dec  1009.0
#
#         Month_y   Amount_y Repay_month
# ...

# %%
Repay_spend['Interest']=(Repay_spend.Amount_x - Repay_spend.Amount_y)*0.029

# %%
Repay_spend.rename(columns={"Amount_x":"Spend_Amount","Amount_y":"Repay_Amount"},inplace=True)

# %%
Repay_spend
# Out:
#       Sl No: Customer    Month_x       Type  Spend_Amount spend_month  SL No:  \
# 0          1       A1 2004-01-12  JEWELLERY     485470.80         Jan     NaN
# 1          1       A1 2004-01-12  JEWELLERY     485470.80         Jan     2.0
# 2          1       A1 2004-01-12  JEWELLERY     485470.80         Jan     3.0
# 3          1       A1 2004-01-12  JEWELLERY     485470.80         Jan     4.0
# 4          1       A1 2004-01-12  JEWELLERY     485470.80         Jan     5.0
# ...      ...      ...        ...        ...           ...         ...     ...
# 5311    1374      A44 2006-12-03  JEWELLERY     313591.17         Dec   997.0
# 5312    1441      A53 2005-04-27  JEWELLERY     129641.87         Apr  1035.0
# 5313    1441      A53 2005-04-27  JEWELLERY     129641.87         Apr  1151.0
# 5314    1441      A53 2005-04-27  JEWELLERY     129641.87         Apr  1325.0
# 5315    1483      A56 2006-12-03  JEWELLERY     223628.27         Dec  1009.0
#
# ...

# %%
Repay_spend[Repay_spend.Interest>0].groupby(by='spend_month').sum().drop(columns=['SL No:','Sl No:']).round(2)
# Out:
#              Spend_Amount  Repay_Amount        Profit    Interest
# spend_month
# Apr          6.039580e+07  3.121577e+07  2.918003e+07   846220.94
# Aug          5.278528e+06  2.703516e+06  2.575012e+06    74675.36
# Dec          1.157146e+06  6.007350e+05  5.564105e+05    16135.90
# Feb          1.411539e+08  6.980606e+07  7.134782e+07  2069086.66
# Jan          3.409866e+08  1.699633e+08  1.710233e+08  4959674.90
# Jul          4.241153e+06  2.823076e+06  1.418077e+06    41124.24
# Jun          1.209917e+07  5.537632e+06  6.561539e+06   190284.63
# Mar          1.376478e+08  7.415847e+07  6.348934e+07  1841190.78
# May          1.454633e+08  7.530770e+07  7.015561e+07  2034512.67
# Nov          1.773818e+07  8.201530e+06  9.536649e+06   276562.82
# Oct          1.478450e+06  9.436247e+05  5.348248e+05    15509.92
# Sep          2.851696e+06  1.186902e+06  1.664794e+06    48279.02

# %%
spend.Type.value_counts()
# Out:
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# SHOPPING        113
# BUS TICKET       99
# JEWELLERY        95
# CLOTHES          95
# RENTAL           76
# MOVIE TICKET     76
# BIKE             49
# AUTO             40
# CAR              30
# SANDALS          28
# Name: Type, dtype: int64

# %%
spend
# Out:
#       Sl No: Customer      Month        Type     Amount spend_month
# 0          1       A1 2004-01-12   JEWELLERY  485470.80         Jan
# 1          2       A1 2004-01-03       PETRO  410556.13         Jan
# 2          3       A1 2004-01-15     CLOTHES   23740.46         Jan
# 3          4       A1 2004-01-25        FOOD  484342.47         Jan
# 4          5       A1 2005-01-17      CAMERA  369694.07         Jan
# ...      ...      ...        ...         ...        ...         ...
# 1495    1496      A67 2006-02-04  BUS TICKET  356872.73         Feb
# 1496    1497      A68 2006-03-25  BUS TICKET  204971.10         Mar
# 1497    1498      A69 2006-03-31  BUS TICKET   50449.44         Mar
# 1498    1499      A70 2006-03-23  BUS TICKET   80593.94         Mar
# 1499    1500      A71 2006-03-24  BUS TICKET  194447.62         Mar
#
# [1500 rows x 6 columns]

# %%
spend.groupby(by='Type').Amount.sum().sort_values(ascending=False).head()
# Out:
# Type
# PETRO           49863174.09
# CAMERA          41481571.96
# FOOD            37773338.43
# TRAIN TICKET    33067077.15
# AIR TICKET      32955445.42
# Name: Amount, dtype: float64

# %%
Customer_acquisition_spend.head(2)
# Out:
#    No Customer  Age       City Product     Limit Company        Segment  \
# 0   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount
# 0  12-Jan-04  JEWELLERY  485470.80
# 1   3-Jan-04      PETRO  410556.13

# %%
Customer_acquisition_spend.groupby(by='City').Amount.sum().sort_values(ascending=False).head(1)
# Out:
# City
# COCHIN    45963513.5
# Name: Amount, dtype: float64

# %%
Customer_acquisition_spend.Age.min()
# Out:
# 12

# %%
Customer_acquisition_spend.Age.max()
# Out:
# 79

# %%
Customer_acquisition_spend['Age_category']=pd.cut(Customer_acquisition_spend.Age,bins=[10,18,30,80],labels=['Teenager','Young adults','Senior'])

# %%
Customer_acquisition_spend.Age_category.value_counts()
# Out:
# Senior          1070
# Young adults     360
# Teenager          70
# Name: Age_category, dtype: int64

# %%
Customer_acquisition_spend.groupby(by='Age_category').Amount.sum().round(1).sort_values(ascending=False).head(1)
# Out:
# Age_category
# Senior    151218635.6
# Name: Amount, dtype: float64

# %%
Repayment.groupby(by='Customer').Amount.sum().sort_values(ascending=False).head(10)
# Out:
# Customer
# A61    10539142.91
# A60     9876290.74
# A13     9572000.66
# A22     9372561.68
# A21     9056336.15
# A43     8489871.46
# A45     8448334.87
# A12     8334760.16
# A48     8292416.75
# A14     7943268.63
# Name: Amount, dtype: float64

# %%
Customer_acquisition_spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No            1500 non-null   int64
#  1   Customer      1500 non-null   object
#  2   Age           1500 non-null   int64
#  3   City          1500 non-null   object
#  4   Product       1500 non-null   object
#  5   Limit         1500 non-null   float64
#  6   Company       1500 non-null   object
#  7   Segment       1500 non-null   object
#  8   Month         1500 non-null   object
#  9   Type          1500 non-null   object
#  10  Amount        1500 non-null   float64
#  11  Age category  1500 non-null   category
#  12  Age_category  1500 non-null   category
# dtypes: category(2), float64(2), int64(2), object(7)
# memory usage: 176.1+ KB

# %%
Customer_acquisition_spend.Month=pd.to_datetime(Customer_acquisition_spend.Month)

# %%
Customer_acquisition_spend['Year']=Customer_acquisition_spend.Month.dt.strftime('%Y')

# %%
Customer_acquisition_spend.head(2)
# Out:
#    No Customer  Age       City Product     Limit Company        Segment  \
# 0   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount Age category Age_category  Year
# 0 2004-01-12  JEWELLERY  485470.80       Senior       Senior  2004
# 1 2004-01-03      PETRO  410556.13       Senior       Senior  2004

# %%
x=pd.pivot_table(data =Customer_acquisition_spend, index = 'City', columns=['Product','Year'], 
               values='Amount', aggfunc='sum')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x.plot(kind='bar',stacked=True)
plt.show()

# %%
Customer_acquisition_spend['Month_Name']=Customer_acquisition_spend.Month.dt.strftime('%b')

# %%
Customer_acquisition_spend.head(2)
# Out:
#    No Customer  Age       City Product     Limit Company        Segment  \
# 0   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount Age category Age_category  Year Month_Name
# 0 2004-01-12  JEWELLERY  485470.80       Senior       Senior  2004        Jan
# 1 2004-01-03      PETRO  410556.13       Senior       Senior  2004        Jan

# %%
y=pd.pivot_table(data =Customer_acquisition_spend, index = 'City', columns=['Month_Name'], 
               values='Amount', aggfunc='sum')

# %%
y
# Out:
# Month_Name         Apr         Aug        Dec         Feb          Jan  \
# City
# BANGALORE   4207980.48   695061.95  422167.24  6734494.76   9041796.84
# BOMBAY      1873785.01  1066744.75  140040.71  4276988.30   5948993.33
# CALCUTTA    3457507.95  1548354.02   55001.50  8150545.61   9064864.90
# CHENNAI     2518656.99   305875.97  223628.27  4385815.95   4466961.36
# COCHIN      3882744.94  2317306.61  909533.05  5747886.38  11714373.54
# DELHI        777240.75   155402.16  842342.02  1494064.06   2714261.45
# PATNA       2338179.53   419383.64   50000.00  2353333.55   4916205.55
# TRIVANDRUM  1199293.45   453773.94  640922.26  2857123.89   3704336.99
#
# Month_Name         Jul         Jun         Mar         May         Nov  \
# City
# BANGALORE   2228217.69  1330685.90  5362903.07  6383115.13  2260603.07
# BOMBAY       177726.32  1172594.97  5227850.50  3891945.60  2872049.40
# CALCUTTA    2234573.27  2293045.81  4939040.04  5578246.87  2078880.93
# ...

# %%
y.plot(kind='bar',figsize=(10,4),stacked=True)
plt.show()

# %%
z=pd.pivot_table(data =Customer_acquisition_spend[Customer_acquisition_spend.Type=='AIR TICKET'], index = 'Year', columns=['Type'], 
               values='Amount', aggfunc='sum')

# %%
z.plot(kind='bar',figsize=(4,4))
plt.show()

# %%
A=pd.pivot_table(data =Customer_acquisition_spend, index = 'Month_Name', columns=['Product'],values='Amount', aggfunc='sum')

# %%
A
# Out:
# Product            Gold     Platimum      Silver
# Month_Name
# Apr         13170572.59   5182493.86  1902322.65
# Aug          4954030.42   1714762.80   293109.82
# Dec          2332940.96    750156.19   200537.90
# Feb         24779179.55   9134054.58  2087018.37
# Jan         32413831.83  14951578.51  4206383.62
# Jul          5167416.37   1288156.26   530153.72
# Jun          6538862.64   2965712.71   689537.61
# Mar         19256972.48   7288837.68  3909405.83
# May         21548169.76   8151926.49  2140940.01
# Nov          9203267.46   2741618.42   691102.63
# Oct          3018223.38    550275.04   100001.50
# Sep          3816887.62   1667840.84   442803.13

# %%
A.plot(kind='bar',figsize=(12,4))
plt.show()

# %%
Customer_acquisition_repayment.dropna(axis=1,how='all',inplace=True)
Customer_acquisition_repayment.head(2)
# Out:
#    No Customer  Age       City Product     Limit Company        Segment  \
# 0   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month     Amount
# 0  12-Jan-04  495414.75
# 1   3-Jan-04  245899.02

# %%
Customer_acquisition_repayment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No        1500 non-null   int64
#  1   Customer  1500 non-null   object
#  2   Age       1500 non-null   int64
#  3   City      1500 non-null   object
#  4   Product   1500 non-null   object
#  5   Limit     1500 non-null   float64
#  6   Company   1500 non-null   object
#  7   Segment   1500 non-null   object
#  8   Month     1500 non-null   object
#  9   Amount    1500 non-null   float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 128.9+ KB

# %%
Customer_acquisition_repayment['Month']=pd.to_datetime(Customer_acquisition_repayment.Month)

# %%
Customer_acquisition_repayment['Month_Name']=Customer_acquisition_repayment.Month.dt.strftime('%b')

# %%
Customer_acquisition_repayment['Year']=Customer_acquisition_repayment.Month.dt.strftime('%Y')

# %%
Customer_acquisition_repayment.head(2)
# Out:
#    No Customer  Age       City Product     Limit Company        Segment  \
# 0   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month     Amount Month_Name  Year
# 0 2004-01-12  495414.75        Jan  2004
# 1 2004-01-03  245899.02        Jan  2004

# %%
def fun_top(prod_category,time_period):
    return Customer_acquisition_repayment.loc[(Customer_acquisition_repayment['Product']==prod_category)&((Customer_acquisition_repayment.Month_Name==time_period)|(Customer_acquisition_repayment.Year==time_period))].groupby(['Customer','Product','City','Month']).Amount.sum().reset_index().sort_values('Amount',ascending=False).head(10)

prod_category=str(input("Select Product - Gold/Silver/Platinum: "))
time_period=input("Enter Time Period in Year(YYYY)/Month_Name(xxx): ")

fun_top(prod_cat,time_period)
# Out:
# Select Product - Gold/Silver/Platinum: Gold
# Enter Time Period in Year(YYYY)/Month_Name(xxx): 2006
#     Customer Product        City      Month     Amount
# 80       A26    Gold       PATNA 2006-05-06  927042.43
# 150      A42    Gold      BOMBAY 2006-05-10  887910.15
# 96       A28    Gold  TRIVANDRUM 2006-03-25  866266.78
# 158      A43    Gold   BANGALORE 2006-07-11  803935.53
# 54       A15    Gold    CALCUTTA 2006-05-06  798879.07
# 172      A60    Gold    CALCUTTA 2006-02-04  756015.49
# 187      A61    Gold      COCHIN 2006-04-19  744357.74
# 53       A15    Gold    CALCUTTA 2006-03-31  738689.53
# 25       A12    Gold      BOMBAY 2006-07-11  703927.69
# 124      A30    Gold   BANGALORE 2006-05-10  644572.12
